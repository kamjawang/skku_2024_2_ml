# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score, roc_auc_score, precision_score, recall_score, f1_score
import torch
import torch.nn as nn
import torch.optim as optim
import sys
sys.path.append("F:/기계학습특론/saint-main/models")  # SAINT 경로 추가
from model import TabAttention  # model.py에서 TabAttention 클래스 임포트

# 데이터 로드 및 전처리
file_path = "adult.csv"
data = pd.read_csv(file_path)

# %%
# '?' 처리 및 결측치 제거
data.replace('?', pd.NA, inplace=True)
data.dropna(inplace=True)

# 범주형 데이터와 연속형 데이터 구분
categorical_columns = ['workclass', 'education', 'marital-status', 'occupation', 
                       'relationship', 'race', 'gender', 'native-country']
continuous_columns = ['age', 'fnlwgt', 'educational-num', 'capital-gain', 'capital-loss', 'hours-per-week']

# %%
# 범주형 데이터 인코딩
label_encoders = {col: LabelEncoder().fit(data[col]) for col in categorical_columns}
for col, encoder in label_encoders.items():
    data[col] = encoder.transform(data[col])

# 타겟 데이터 인코딩
data['income'] = (data['income'] == '>50K').astype(int)

# 입력 데이터 분리
X = data.drop("income", axis=1)
y = data["income"]

# 범주형 및 연속형 데이터 분리
X_categ = X[categorical_columns].values
X_cont = X[continuous_columns].values

# 데이터 분할
X_categ_train, X_categ_test, X_cont_train, X_cont_test, y_train, y_test = train_test_split(
    X_categ, X_cont, y, test_size=0.2, random_state=42
)

# %%
# 연속형 데이터 정규화
scaler = StandardScaler()
X_cont_train = scaler.fit_transform(X_cont_train)
X_cont_test = scaler.transform(X_cont_test)

# PyTorch 텐서로 변환
X_categ_train_tensor = torch.tensor(X_categ_train, dtype=torch.long)
X_cont_train_tensor = torch.tensor(X_cont_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train.values, dtype=torch.float32)

X_categ_test_tensor = torch.tensor(X_categ_test, dtype=torch.long)
X_cont_test_tensor = torch.tensor(X_cont_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test.values, dtype=torch.float32)

# %%
# 모델 초기화
model = TabAttention(
    categories=[len(data[col].unique()) for col in categorical_columns],
    num_continuous=len(continuous_columns),
    dim=16,  # 작은 임베딩 차원
    depth=3,  # Transformer 레이어 수 축소
    heads=4,  # Multi-head Attention 수 축소
    dim_head=8,
    dim_out=1,
    mlp_hidden_mults=(2, 1),
    mlp_act=nn.ReLU(),
    attentiontype="col"
)

# %%
# 인코딩 텐서 생성
def create_encodings(x_categ, x_cont, model):
    device = x_categ.device
    x_categ_enc = model.embeds(x_categ + model.categories_offset.to(device))
    x_cont_enc = torch.cat([
        model.simple_MLP[i](x_cont[:, i:i + 1]) for i in range(x_cont.shape[1])
    ], dim=1)
    return x_categ_enc, x_cont_enc

x_categ_train_enc, x_cont_train_enc = create_encodings(X_categ_train_tensor, X_cont_train_tensor, model)
x_categ_test_enc, x_cont_test_enc = create_encodings(X_categ_test_tensor, X_cont_test_tensor, model)

# %%
# 차원 확장 및 크기 맞춤
x_cont_train_enc = x_cont_train_enc.unsqueeze(1).expand(-1, x_categ_train_enc.size(1), -1)
x_cont_test_enc = x_cont_test_enc.unsqueeze(1).expand(-1, x_categ_test_enc.size(1), -1)

# 연속형 임베딩 크기를 카테고리 임베딩 크기와 맞추기
if x_cont_train_enc.size(-1) != x_categ_train_enc.size(-1):
    linear_adjust = nn.Linear(x_cont_train_enc.size(-1), x_categ_train_enc.size(-1))
    x_cont_train_enc = linear_adjust(x_cont_train_enc)
    x_cont_test_enc = linear_adjust(x_cont_test_enc)

# 디버깅: 최종 입력 크기 확인
flat_x_size = (x_categ_train_enc.size(1) * x_categ_train_enc.size(2)) + \
              (x_cont_train_enc.size(1) * x_cont_train_enc.size(2))
print(f"Final flattened input size: {flat_x_size}")

# TabAttention 모델 수정: MLP의 입력 크기 동적으로 설정
model.mlp = nn.Sequential(
    nn.Linear(flat_x_size, 128),  # 첫 번째 레이어의 입력 크기 동적으로 설정
    nn.ReLU(),
    nn.Linear(128, 1)
)
# Out:
# Final flattened input size: 256

# %%
# CPU 설정
device = torch.device("cpu")
model.to(device)

# 손실 함수 및 옵티마이저 정의
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# 디버깅: 모델 크기 확인
print("Model Parameters:")
print(f"Categorical Features: {X_categ_train_tensor.shape}")
print(f"Continuous Features: {X_cont_train_tensor.shape}")
# Out:
# Model Parameters:
# Categorical Features: torch.Size([36177, 8])
# Continuous Features: torch.Size([36177, 6])

# %%
# 학습
epochs = 200
for epoch in range(epochs):
    model.train()
    optimizer.zero_grad()

    # 모델 출력
    outputs = model(X_categ_train_tensor, X_cont_train_tensor, x_categ_train_enc.detach(), x_cont_train_enc.detach()).squeeze()

    # 디버깅: detach()로 그래프에서 분리된 값을 사용
    print(f"Epoch {epoch + 1} - Model Output: Shape = {outputs.shape}, requires_grad = {outputs.requires_grad}")
    
    # 손실 계산
    loss = criterion(outputs, y_train_tensor)
    loss_value = loss.item()  # 손실 값 분리
    print(f"Epoch {epoch + 1} - Loss: {loss_value}, requires_grad = {loss.requires_grad}")

    # 역전파
    loss.backward()  # retain_graph를 사용하지 않도록 기본값 유지
    optimizer.step()

    # 디버깅 출력
    print(f"Epoch {epoch + 1}/{epochs}, Loss: {loss_value}")
# Out:
# Epoch 1 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 1 - Loss: 0.7430999875068665, requires_grad = True
# Epoch 1/200, Loss: 0.7430999875068665
# Epoch 2 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 2 - Loss: 0.5968636870384216, requires_grad = True
# Epoch 2/200, Loss: 0.5968636870384216
# Epoch 3 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 3 - Loss: 0.5411301255226135, requires_grad = True
# Epoch 3/200, Loss: 0.5411301255226135
# Epoch 4 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 4 - Loss: 0.5321691036224365, requires_grad = True
# Epoch 4/200, Loss: 0.5321691036224365
# Epoch 5 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 5 - Loss: 0.5290831327438354, requires_grad = True
# Epoch 5/200, Loss: 0.5290831327438354
# Epoch 6 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 6 - Loss: 0.5131364464759827, requires_grad = True
# Epoch 6/200, Loss: 0.5131364464759827
# Epoch 7 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 7 - Loss: 0.48629799485206604, requires_grad = True
# Epoch 7/200, Loss: 0.48629799485206604
# Epoch 8 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 8 - Loss: 0.45776796340942383, requires_grad = True
# Epoch 8/200, Loss: 0.45776796340942383
# Epoch 9 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 9 - Loss: 0.43619823455810547, requires_grad = True
# Epoch 9/200, Loss: 0.43619823455810547
# Epoch 10 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 10 - Loss: 0.42574673891067505, requires_grad = True
# Epoch 10/200, Loss: 0.42574673891067505
# Epoch 11 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 11 - Loss: 0.4234590530395508, requires_grad = True
# Epoch 11/200, Loss: 0.4234590530395508
# Epoch 12 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 12 - Loss: 0.4206894338130951, requires_grad = True
# Epoch 12/200, Loss: 0.4206894338130951
# Epoch 13 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 13 - Loss: 0.4116855561733246, requires_grad = True
# Epoch 13/200, Loss: 0.4116855561733246
# Epoch 14 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 14 - Loss: 0.3982766568660736, requires_grad = True
# Epoch 14/200, Loss: 0.3982766568660736
# Epoch 15 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 15 - Loss: 0.38631707429885864, requires_grad = True
# Epoch 15/200, Loss: 0.38631707429885864
# Epoch 16 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 16 - Loss: 0.3803780972957611, requires_grad = True
# Epoch 16/200, Loss: 0.3803780972957611
# Epoch 17 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 17 - Loss: 0.3802008330821991, requires_grad = True
# Epoch 17/200, Loss: 0.3802008330821991
# Epoch 18 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 18 - Loss: 0.380855530500412, requires_grad = True
# Epoch 18/200, Loss: 0.380855530500412
# Epoch 19 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 19 - Loss: 0.37782031297683716, requires_grad = True
# Epoch 19/200, Loss: 0.37782031297683716
# Epoch 20 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 20 - Loss: 0.3713640570640564, requires_grad = True
# Epoch 20/200, Loss: 0.3713640570640564
# Epoch 21 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 21 - Loss: 0.36528706550598145, requires_grad = True
# Epoch 21/200, Loss: 0.36528706550598145
# Epoch 22 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 22 - Loss: 0.36307668685913086, requires_grad = True
# Epoch 22/200, Loss: 0.36307668685913086
# Epoch 23 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 23 - Loss: 0.36399754881858826, requires_grad = True
# Epoch 23/200, Loss: 0.36399754881858826
# Epoch 24 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 24 - Loss: 0.3633434474468231, requires_grad = True
# Epoch 24/200, Loss: 0.3633434474468231
# Epoch 25 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 25 - Loss: 0.3588370084762573, requires_grad = True
# Epoch 25/200, Loss: 0.3588370084762573
# Epoch 26 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 26 - Loss: 0.3533186614513397, requires_grad = True
# Epoch 26/200, Loss: 0.3533186614513397
# Epoch 27 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 27 - Loss: 0.3503124415874481, requires_grad = True
# Epoch 27/200, Loss: 0.3503124415874481
# Epoch 28 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 28 - Loss: 0.34965482354164124, requires_grad = True
# Epoch 28/200, Loss: 0.34965482354164124
# Epoch 29 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 29 - Loss: 0.34822654724121094, requires_grad = True
# Epoch 29/200, Loss: 0.34822654724121094
# Epoch 30 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 30 - Loss: 0.3444293737411499, requires_grad = True
# Epoch 30/200, Loss: 0.3444293737411499
# Epoch 31 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 31 - Loss: 0.3401105999946594, requires_grad = True
# Epoch 31/200, Loss: 0.3401105999946594
# Epoch 32 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 32 - Loss: 0.33801695704460144, requires_grad = True
# Epoch 32/200, Loss: 0.33801695704460144
# Epoch 33 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 33 - Loss: 0.3377562463283539, requires_grad = True
# Epoch 33/200, Loss: 0.3377562463283539
# Epoch 34 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 34 - Loss: 0.3362490236759186, requires_grad = True
# Epoch 34/200, Loss: 0.3362490236759186
# Epoch 35 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 35 - Loss: 0.3332866430282593, requires_grad = True
# Epoch 35/200, Loss: 0.3332866430282593
# Epoch 36 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 36 - Loss: 0.33165210485458374, requires_grad = True
# Epoch 36/200, Loss: 0.33165210485458374
# Epoch 37 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 37 - Loss: 0.33179548382759094, requires_grad = True
# Epoch 37/200, Loss: 0.33179548382759094
# Epoch 38 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 38 - Loss: 0.331257164478302, requires_grad = True
# Epoch 38/200, Loss: 0.331257164478302
# Epoch 39 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 39 - Loss: 0.3293229639530182, requires_grad = True
# Epoch 39/200, Loss: 0.3293229639530182
# Epoch 40 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 40 - Loss: 0.32817667722702026, requires_grad = True
# Epoch 40/200, Loss: 0.32817667722702026
# Epoch 41 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 41 - Loss: 0.3284907937049866, requires_grad = True
# Epoch 41/200, Loss: 0.3284907937049866
# Epoch 42 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 42 - Loss: 0.3277585804462433, requires_grad = True
# Epoch 42/200, Loss: 0.3277585804462433
# Epoch 43 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 43 - Loss: 0.3262527585029602, requires_grad = True
# Epoch 43/200, Loss: 0.3262527585029602
# Epoch 44 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 44 - Loss: 0.32607805728912354, requires_grad = True
# Epoch 44/200, Loss: 0.32607805728912354
# Epoch 45 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 45 - Loss: 0.3261122703552246, requires_grad = True
# Epoch 45/200, Loss: 0.3261122703552246
# Epoch 46 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 46 - Loss: 0.3250716030597687, requires_grad = True
# Epoch 46/200, Loss: 0.3250716030597687
# Epoch 47 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 47 - Loss: 0.3242601156234741, requires_grad = True
# Epoch 47/200, Loss: 0.3242601156234741
# Epoch 48 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 48 - Loss: 0.32427191734313965, requires_grad = True
# Epoch 48/200, Loss: 0.32427191734313965
# Epoch 49 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 49 - Loss: 0.32370150089263916, requires_grad = True
# Epoch 49/200, Loss: 0.32370150089263916
# Epoch 50 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 50 - Loss: 0.32276651263237, requires_grad = True
# Epoch 50/200, Loss: 0.32276651263237
# Epoch 51 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 51 - Loss: 0.3225124776363373, requires_grad = True
# Epoch 51/200, Loss: 0.3225124776363373
# Epoch 52 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 52 - Loss: 0.3223351538181305, requires_grad = True
# Epoch 52/200, Loss: 0.3223351538181305
# Epoch 53 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 53 - Loss: 0.3216928243637085, requires_grad = True
# Epoch 53/200, Loss: 0.3216928243637085
# Epoch 54 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 54 - Loss: 0.32122671604156494, requires_grad = True
# Epoch 54/200, Loss: 0.32122671604156494
# Epoch 55 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 55 - Loss: 0.3211371600627899, requires_grad = True
# Epoch 55/200, Loss: 0.3211371600627899
# Epoch 56 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 56 - Loss: 0.32079872488975525, requires_grad = True
# Epoch 56/200, Loss: 0.32079872488975525
# Epoch 57 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 57 - Loss: 0.3202676773071289, requires_grad = True
# Epoch 57/200, Loss: 0.3202676773071289
# Epoch 58 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 58 - Loss: 0.32000577449798584, requires_grad = True
# Epoch 58/200, Loss: 0.32000577449798584
# Epoch 59 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 59 - Loss: 0.3198185861110687, requires_grad = True
# Epoch 59/200, Loss: 0.3198185861110687
# Epoch 60 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 60 - Loss: 0.31940722465515137, requires_grad = True
# Epoch 60/200, Loss: 0.31940722465515137
# Epoch 61 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 61 - Loss: 0.3190140724182129, requires_grad = True
# Epoch 61/200, Loss: 0.3190140724182129
# Epoch 62 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 62 - Loss: 0.318815678358078, requires_grad = True
# Epoch 62/200, Loss: 0.318815678358078
# Epoch 63 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 63 - Loss: 0.3185517489910126, requires_grad = True
# Epoch 63/200, Loss: 0.3185517489910126
# Epoch 64 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 64 - Loss: 0.31817591190338135, requires_grad = True
# Epoch 64/200, Loss: 0.31817591190338135
# Epoch 65 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 65 - Loss: 0.3179352879524231, requires_grad = True
# Epoch 65/200, Loss: 0.3179352879524231
# Epoch 66 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 66 - Loss: 0.3177776038646698, requires_grad = True
# Epoch 66/200, Loss: 0.3177776038646698
# Epoch 67 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 67 - Loss: 0.3175181746482849, requires_grad = True
# Epoch 67/200, Loss: 0.3175181746482849
# Epoch 68 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 68 - Loss: 0.3172715902328491, requires_grad = True
# Epoch 68/200, Loss: 0.3172715902328491
# Epoch 69 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 69 - Loss: 0.3171340227127075, requires_grad = True
# Epoch 69/200, Loss: 0.3171340227127075
# Epoch 70 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 70 - Loss: 0.31693851947784424, requires_grad = True
# Epoch 70/200, Loss: 0.31693851947784424
# Epoch 71 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 71 - Loss: 0.31668394804000854, requires_grad = True
# Epoch 71/200, Loss: 0.31668394804000854
# Epoch 72 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 72 - Loss: 0.31651365756988525, requires_grad = True
# Epoch 72/200, Loss: 0.31651365756988525
# Epoch 73 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 73 - Loss: 0.3163442015647888, requires_grad = True
# Epoch 73/200, Loss: 0.3163442015647888
# Epoch 74 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 74 - Loss: 0.3161136507987976, requires_grad = True
# Epoch 74/200, Loss: 0.3161136507987976
# Epoch 75 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 75 - Loss: 0.3159334659576416, requires_grad = True
# Epoch 75/200, Loss: 0.3159334659576416
# Epoch 76 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 76 - Loss: 0.31578534841537476, requires_grad = True
# Epoch 76/200, Loss: 0.31578534841537476
# Epoch 77 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 77 - Loss: 0.3155849277973175, requires_grad = True
# Epoch 77/200, Loss: 0.3155849277973175
# Epoch 78 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 78 - Loss: 0.31540992856025696, requires_grad = True
# Epoch 78/200, Loss: 0.31540992856025696
# Epoch 79 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 79 - Loss: 0.315273642539978, requires_grad = True
# Epoch 79/200, Loss: 0.315273642539978
# Epoch 80 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 80 - Loss: 0.3151029348373413, requires_grad = True
# Epoch 80/200, Loss: 0.3151029348373413
# Epoch 81 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 81 - Loss: 0.3149411082267761, requires_grad = True
# Epoch 81/200, Loss: 0.3149411082267761
# Epoch 82 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 82 - Loss: 0.314812034368515, requires_grad = True
# Epoch 82/200, Loss: 0.314812034368515
# Epoch 83 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 83 - Loss: 0.3146550953388214, requires_grad = True
# Epoch 83/200, Loss: 0.3146550953388214
# Epoch 84 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 84 - Loss: 0.31449782848358154, requires_grad = True
# Epoch 84/200, Loss: 0.31449782848358154
# Epoch 85 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 85 - Loss: 0.3143666386604309, requires_grad = True
# Epoch 85/200, Loss: 0.3143666386604309
# Epoch 86 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 86 - Loss: 0.3142169415950775, requires_grad = True
# Epoch 86/200, Loss: 0.3142169415950775
# Epoch 87 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 87 - Loss: 0.3140709102153778, requires_grad = True
# Epoch 87/200, Loss: 0.3140709102153778
# Epoch 88 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 88 - Loss: 0.31394708156585693, requires_grad = True
# Epoch 88/200, Loss: 0.31394708156585693
# Epoch 89 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 89 - Loss: 0.31381094455718994, requires_grad = True
# Epoch 89/200, Loss: 0.31381094455718994
# Epoch 90 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 90 - Loss: 0.3136806786060333, requires_grad = True
# Epoch 90/200, Loss: 0.3136806786060333
# Epoch 91 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 91 - Loss: 0.3135634958744049, requires_grad = True
# Epoch 91/200, Loss: 0.3135634958744049
# Epoch 92 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 92 - Loss: 0.313433438539505, requires_grad = True
# Epoch 92/200, Loss: 0.313433438539505
# Epoch 93 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 93 - Loss: 0.31330910325050354, requires_grad = True
# Epoch 93/200, Loss: 0.31330910325050354
# Epoch 94 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 94 - Loss: 0.31319084763526917, requires_grad = True
# Epoch 94/200, Loss: 0.31319084763526917
# Epoch 95 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 95 - Loss: 0.313062459230423, requires_grad = True
# Epoch 95/200, Loss: 0.313062459230423
# Epoch 96 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 96 - Loss: 0.3129423260688782, requires_grad = True
# Epoch 96/200, Loss: 0.3129423260688782
# Epoch 97 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 97 - Loss: 0.31282302737236023, requires_grad = True
# Epoch 97/200, Loss: 0.31282302737236023
# Epoch 98 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 98 - Loss: 0.3126986622810364, requires_grad = True
# Epoch 98/200, Loss: 0.3126986622810364
# Epoch 99 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 99 - Loss: 0.3125830590724945, requires_grad = True
# Epoch 99/200, Loss: 0.3125830590724945
# Epoch 100 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 100 - Loss: 0.31246668100357056, requires_grad = True
# Epoch 100/200, Loss: 0.31246668100357056
# Epoch 101 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 101 - Loss: 0.31234925985336304, requires_grad = True
# Epoch 101/200, Loss: 0.31234925985336304
# Epoch 102 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 102 - Loss: 0.3122376799583435, requires_grad = True
# Epoch 102/200, Loss: 0.3122376799583435
# Epoch 103 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 103 - Loss: 0.3121229410171509, requires_grad = True
# Epoch 103/200, Loss: 0.3121229410171509
# Epoch 104 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 104 - Loss: 0.31201016902923584, requires_grad = True
# Epoch 104/200, Loss: 0.31201016902923584
# Epoch 105 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 105 - Loss: 0.3119000196456909, requires_grad = True
# Epoch 105/200, Loss: 0.3119000196456909
# Epoch 106 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 106 - Loss: 0.3117876946926117, requires_grad = True
# Epoch 106/200, Loss: 0.3117876946926117
# Epoch 107 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 107 - Loss: 0.3116784989833832, requires_grad = True
# Epoch 107/200, Loss: 0.3116784989833832
# Epoch 108 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 108 - Loss: 0.31156912446022034, requires_grad = True
# Epoch 108/200, Loss: 0.31156912446022034
# Epoch 109 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 109 - Loss: 0.31145912408828735, requires_grad = True
# Epoch 109/200, Loss: 0.31145912408828735
# Epoch 110 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 110 - Loss: 0.3113516867160797, requires_grad = True
# Epoch 110/200, Loss: 0.3113516867160797
# Epoch 111 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 111 - Loss: 0.3112421929836273, requires_grad = True
# Epoch 111/200, Loss: 0.3112421929836273
# Epoch 112 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 112 - Loss: 0.31113335490226746, requires_grad = True
# Epoch 112/200, Loss: 0.31113335490226746
# Epoch 113 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 113 - Loss: 0.3110245168209076, requires_grad = True
# Epoch 113/200, Loss: 0.3110245168209076
# Epoch 114 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 114 - Loss: 0.31091469526290894, requires_grad = True
# Epoch 114/200, Loss: 0.31091469526290894
# Epoch 115 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 115 - Loss: 0.31080690026283264, requires_grad = True
# Epoch 115/200, Loss: 0.31080690026283264
# Epoch 116 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 116 - Loss: 0.3106992840766907, requires_grad = True
# Epoch 116/200, Loss: 0.3106992840766907
# Epoch 117 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 117 - Loss: 0.31059256196022034, requires_grad = True
# Epoch 117/200, Loss: 0.31059256196022034
# Epoch 118 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 118 - Loss: 0.3104865252971649, requires_grad = True
# Epoch 118/200, Loss: 0.3104865252971649
# Epoch 119 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 119 - Loss: 0.3103804886341095, requires_grad = True
# Epoch 119/200, Loss: 0.3103804886341095
# Epoch 120 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 120 - Loss: 0.3102762997150421, requires_grad = True
# Epoch 120/200, Loss: 0.3102762997150421
# Epoch 121 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 121 - Loss: 0.3101711869239807, requires_grad = True
# Epoch 121/200, Loss: 0.3101711869239807
# Epoch 122 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 122 - Loss: 0.3100663423538208, requires_grad = True
# Epoch 122/200, Loss: 0.3100663423538208
# Epoch 123 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 123 - Loss: 0.3099624812602997, requires_grad = True
# Epoch 123/200, Loss: 0.3099624812602997
# Epoch 124 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 124 - Loss: 0.30985894799232483, requires_grad = True
# Epoch 124/200, Loss: 0.30985894799232483
# Epoch 125 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 125 - Loss: 0.30975648760795593, requires_grad = True
# Epoch 125/200, Loss: 0.30975648760795593
# Epoch 126 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 126 - Loss: 0.3096536695957184, requires_grad = True
# Epoch 126/200, Loss: 0.3096536695957184
# Epoch 127 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 127 - Loss: 0.3095517158508301, requires_grad = True
# Epoch 127/200, Loss: 0.3095517158508301
# Epoch 128 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 128 - Loss: 0.3094497323036194, requires_grad = True
# Epoch 128/200, Loss: 0.3094497323036194
# Epoch 129 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 129 - Loss: 0.309347927570343, requires_grad = True
# Epoch 129/200, Loss: 0.309347927570343
# Epoch 130 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 130 - Loss: 0.30924636125564575, requires_grad = True
# Epoch 130/200, Loss: 0.30924636125564575
# Epoch 131 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 131 - Loss: 0.30914506316185, requires_grad = True
# Epoch 131/200, Loss: 0.30914506316185
# Epoch 132 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 132 - Loss: 0.3090445399284363, requires_grad = True
# Epoch 132/200, Loss: 0.3090445399284363
# Epoch 133 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 133 - Loss: 0.30894389748573303, requires_grad = True
# Epoch 133/200, Loss: 0.30894389748573303
# Epoch 134 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 134 - Loss: 0.30884382128715515, requires_grad = True
# Epoch 134/200, Loss: 0.30884382128715515
# Epoch 135 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 135 - Loss: 0.30874350666999817, requires_grad = True
# Epoch 135/200, Loss: 0.30874350666999817
# Epoch 136 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 136 - Loss: 0.30864331126213074, requires_grad = True
# Epoch 136/200, Loss: 0.30864331126213074
# Epoch 137 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 137 - Loss: 0.30854296684265137, requires_grad = True
# Epoch 137/200, Loss: 0.30854296684265137
# Epoch 138 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 138 - Loss: 0.3084428012371063, requires_grad = True
# Epoch 138/200, Loss: 0.3084428012371063
# Epoch 139 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 139 - Loss: 0.30834275484085083, requires_grad = True
# Epoch 139/200, Loss: 0.30834275484085083
# Epoch 140 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 140 - Loss: 0.3082430064678192, requires_grad = True
# Epoch 140/200, Loss: 0.3082430064678192
# Epoch 141 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 141 - Loss: 0.30814439058303833, requires_grad = True
# Epoch 141/200, Loss: 0.30814439058303833
# Epoch 142 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 142 - Loss: 0.30804523825645447, requires_grad = True
# Epoch 142/200, Loss: 0.30804523825645447
# Epoch 143 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 143 - Loss: 0.3079461455345154, requires_grad = True
# Epoch 143/200, Loss: 0.3079461455345154
# Epoch 144 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 144 - Loss: 0.3078468441963196, requires_grad = True
# Epoch 144/200, Loss: 0.3078468441963196
# Epoch 145 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 145 - Loss: 0.30774834752082825, requires_grad = True
# Epoch 145/200, Loss: 0.30774834752082825
# Epoch 146 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 146 - Loss: 0.3076498508453369, requires_grad = True
# Epoch 146/200, Loss: 0.3076498508453369
# Epoch 147 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 147 - Loss: 0.30755096673965454, requires_grad = True
# Epoch 147/200, Loss: 0.30755096673965454
# Epoch 148 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 148 - Loss: 0.30745118856430054, requires_grad = True
# Epoch 148/200, Loss: 0.30745118856430054
# Epoch 149 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 149 - Loss: 0.30735117197036743, requires_grad = True
# Epoch 149/200, Loss: 0.30735117197036743
# Epoch 150 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 150 - Loss: 0.3072511553764343, requires_grad = True
# Epoch 150/200, Loss: 0.3072511553764343
# Epoch 151 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 151 - Loss: 0.30715200304985046, requires_grad = True
# Epoch 151/200, Loss: 0.30715200304985046
# Epoch 152 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 152 - Loss: 0.3070535659790039, requires_grad = True
# Epoch 152/200, Loss: 0.3070535659790039
# Epoch 153 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 153 - Loss: 0.3069545030593872, requires_grad = True
# Epoch 153/200, Loss: 0.3069545030593872
# Epoch 154 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 154 - Loss: 0.3068561851978302, requires_grad = True
# Epoch 154/200, Loss: 0.3068561851978302
# Epoch 155 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 155 - Loss: 0.30675801634788513, requires_grad = True
# Epoch 155/200, Loss: 0.30675801634788513
# Epoch 156 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 156 - Loss: 0.30665940046310425, requires_grad = True
# Epoch 156/200, Loss: 0.30665940046310425
# Epoch 157 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 157 - Loss: 0.30656054615974426, requires_grad = True
# Epoch 157/200, Loss: 0.30656054615974426
# Epoch 158 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 158 - Loss: 0.3064620792865753, requires_grad = True
# Epoch 158/200, Loss: 0.3064620792865753
# Epoch 159 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 159 - Loss: 0.3063630163669586, requires_grad = True
# Epoch 159/200, Loss: 0.3063630163669586
# Epoch 160 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 160 - Loss: 0.3062639534473419, requires_grad = True
# Epoch 160/200, Loss: 0.3062639534473419
# Epoch 161 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 161 - Loss: 0.3061651587486267, requires_grad = True
# Epoch 161/200, Loss: 0.3061651587486267
# Epoch 162 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 162 - Loss: 0.3060661852359772, requires_grad = True
# Epoch 162/200, Loss: 0.3060661852359772
# Epoch 163 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 163 - Loss: 0.30596646666526794, requires_grad = True
# Epoch 163/200, Loss: 0.30596646666526794
# Epoch 164 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 164 - Loss: 0.305866539478302, requires_grad = True
# Epoch 164/200, Loss: 0.305866539478302
# Epoch 165 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 165 - Loss: 0.30576643347740173, requires_grad = True
# Epoch 165/200, Loss: 0.30576643347740173
# Epoch 166 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 166 - Loss: 0.30566591024398804, requires_grad = True
# Epoch 166/200, Loss: 0.30566591024398804
# Epoch 167 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 167 - Loss: 0.30556538701057434, requires_grad = True
# Epoch 167/200, Loss: 0.30556538701057434
# Epoch 168 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 168 - Loss: 0.3054641783237457, requires_grad = True
# Epoch 168/200, Loss: 0.3054641783237457
# Epoch 169 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 169 - Loss: 0.30536288022994995, requires_grad = True
# Epoch 169/200, Loss: 0.30536288022994995
# Epoch 170 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 170 - Loss: 0.3052610754966736, requires_grad = True
# Epoch 170/200, Loss: 0.3052610754966736
# Epoch 171 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 171 - Loss: 0.3051593005657196, requires_grad = True
# Epoch 171/200, Loss: 0.3051593005657196
# Epoch 172 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 172 - Loss: 0.3050577640533447, requires_grad = True
# Epoch 172/200, Loss: 0.3050577640533447
# Epoch 173 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 173 - Loss: 0.30495619773864746, requires_grad = True
# Epoch 173/200, Loss: 0.30495619773864746
# Epoch 174 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 174 - Loss: 0.3048538565635681, requires_grad = True
# Epoch 174/200, Loss: 0.3048538565635681
# Epoch 175 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 175 - Loss: 0.3047516345977783, requires_grad = True
# Epoch 175/200, Loss: 0.3047516345977783
# Epoch 176 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 176 - Loss: 0.3046496510505676, requires_grad = True
# Epoch 176/200, Loss: 0.3046496510505676
# Epoch 177 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 177 - Loss: 0.3045467436313629, requires_grad = True
# Epoch 177/200, Loss: 0.3045467436313629
# Epoch 178 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 178 - Loss: 0.30444347858428955, requires_grad = True
# Epoch 178/200, Loss: 0.30444347858428955
# Epoch 179 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 179 - Loss: 0.3043398857116699, requires_grad = True
# Epoch 179/200, Loss: 0.3043398857116699
# Epoch 180 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 180 - Loss: 0.3042363226413727, requires_grad = True
# Epoch 180/200, Loss: 0.3042363226413727
# Epoch 181 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 181 - Loss: 0.30413275957107544, requires_grad = True
# Epoch 181/200, Loss: 0.30413275957107544
# Epoch 182 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 182 - Loss: 0.3040291666984558, requires_grad = True
# Epoch 182/200, Loss: 0.3040291666984558
# Epoch 183 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 183 - Loss: 0.30392563343048096, requires_grad = True
# Epoch 183/200, Loss: 0.30392563343048096
# Epoch 184 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 184 - Loss: 0.3038220703601837, requires_grad = True
# Epoch 184/200, Loss: 0.3038220703601837
# Epoch 185 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 185 - Loss: 0.3037182092666626, requires_grad = True
# Epoch 185/200, Loss: 0.3037182092666626
# Epoch 186 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 186 - Loss: 0.3036141097545624, requires_grad = True
# Epoch 186/200, Loss: 0.3036141097545624
# Epoch 187 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 187 - Loss: 0.3035098910331726, requires_grad = True
# Epoch 187/200, Loss: 0.3035098910331726
# Epoch 188 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 188 - Loss: 0.30340513586997986, requires_grad = True
# Epoch 188/200, Loss: 0.30340513586997986
# Epoch 189 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 189 - Loss: 0.3032999634742737, requires_grad = True
# Epoch 189/200, Loss: 0.3032999634742737
# Epoch 190 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 190 - Loss: 0.3031938672065735, requires_grad = True
# Epoch 190/200, Loss: 0.3031938672065735
# Epoch 191 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 191 - Loss: 0.303087443113327, requires_grad = True
# Epoch 191/200, Loss: 0.303087443113327
# Epoch 192 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 192 - Loss: 0.3029811680316925, requires_grad = True
# Epoch 192/200, Loss: 0.3029811680316925
# Epoch 193 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 193 - Loss: 0.3028748631477356, requires_grad = True
# Epoch 193/200, Loss: 0.3028748631477356
# Epoch 194 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 194 - Loss: 0.3027685284614563, requires_grad = True
# Epoch 194/200, Loss: 0.3027685284614563
# Epoch 195 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 195 - Loss: 0.30266180634498596, requires_grad = True
# Epoch 195/200, Loss: 0.30266180634498596
# Epoch 196 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 196 - Loss: 0.3025552034378052, requires_grad = True
# Epoch 196/200, Loss: 0.3025552034378052
# Epoch 197 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 197 - Loss: 0.30244889855384827, requires_grad = True
# Epoch 197/200, Loss: 0.30244889855384827
# Epoch 198 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 198 - Loss: 0.3023430109024048, requires_grad = True
# Epoch 198/200, Loss: 0.3023430109024048
# Epoch 199 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 199 - Loss: 0.3022366464138031, requires_grad = True
# Epoch 199/200, Loss: 0.3022366464138031
# Epoch 200 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 200 - Loss: 0.3021312355995178, requires_grad = True
# Epoch 200/200, Loss: 0.3021312355995178

# %%
from sklearn.metrics import confusion_matrix

# 평가
model.eval()
with torch.no_grad():
    predictions = model(X_categ_test_tensor, X_cont_test_tensor, x_categ_test_enc, x_cont_test_enc).squeeze()
    predictions = torch.sigmoid(predictions).cpu().numpy()
    pred_labels = (predictions > 0.5).astype(int)

    # 성능 지표 계산
    accuracy = accuracy_score(y_test, pred_labels)
    auroc = roc_auc_score(y_test, predictions)
    precision = precision_score(y_test, pred_labels)
    recall = recall_score(y_test, pred_labels)
    f1 = f1_score(y_test, pred_labels)

    # 공정성 지표 계산
    sensitive_attr = X_categ_test_tensor[:, categorical_columns.index('gender')].cpu().numpy()  # gender 컬럼
    group_0 = sensitive_attr == 0  # 예: 남성
    group_1 = sensitive_attr == 1  # 예: 여성

    # Demographic Parity
    dp = abs(pred_labels[group_0].mean() - pred_labels[group_1].mean())

    # Equal Opportunity
    eo = abs(pred_labels[group_0 & (y_test == 1)].mean() - pred_labels[group_1 & (y_test == 1)].mean())

    # Equality of Odds
    group_0_tpr = pred_labels[group_0 & (y_test == 1)].mean()
    group_1_tpr = pred_labels[group_1 & (y_test == 1)].mean()
    group_0_fpr = pred_labels[group_0 & (y_test == 0)].mean()
    group_1_fpr = pred_labels[group_1 & (y_test == 0)].mean()
    eop = abs(group_0_tpr - group_1_tpr) + abs(group_0_fpr - group_1_fpr)

# 평가 결과 출력
print("\n모델 평가 결과:")
print(f"정확도 (Accuracy): {accuracy:.4f}")
print(f"AUROC: {auroc:.4f}")
print(f"정밀도 (Precision): {precision:.4f}")
print(f"재현율 (Recall): {recall:.4f}")
print(f"F1 점수 (F1-Score): {f1:.4f}")

# 공정성 지표 출력
print("\n공정성 지표:")
print(f"Demographic Parity (DP): {dp:.4f}")
print(f"Equal Opportunity (EO): {eo:.4f}")
print(f"Equality of Odds (EOP): {eop:.4f}")
# Out:
# 모델 평가 결과:
# 정확도 (Accuracy): 0.8587
# AUROC: 0.9142
# 정밀도 (Precision): 0.7520
# 재현율 (Recall): 0.6264
# F1 점수 (F1-Score): 0.6835
#
# 공정성 지표:
# Demographic Parity (DP): 0.1815
# Equal Opportunity (EO): 0.1082
# Equality of Odds (EOP): 0.1805
