# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score, roc_auc_score, precision_score, recall_score, f1_score
import torch
import torch.nn as nn
import torch.optim as optim
import sys
sys.path.append("F:/기계학습특론/saint-main/models")  # SAINT 경로 추가
from model import TabAttention  # model.py에서 TabAttention 클래스 임포트

# 데이터 로드 및 전처리
file_path = "adult.csv"
data = pd.read_csv(file_path)

# %%
# '?' 처리 및 결측치 제거
data.replace('?', pd.NA, inplace=True)
data.dropna(inplace=True)

# 범주형 데이터와 연속형 데이터 구분
categorical_columns = ['workclass', 'education', 'marital-status', 'occupation', 
                       'relationship', 'race', 'gender', 'native-country']
continuous_columns = ['age', 'fnlwgt', 'educational-num', 'capital-gain', 'capital-loss', 'hours-per-week']

# %%
# 범주형 데이터 인코딩
label_encoders = {col: LabelEncoder().fit(data[col]) for col in categorical_columns}
for col, encoder in label_encoders.items():
    data[col] = encoder.transform(data[col])

# 타겟 데이터 인코딩
data['income'] = (data['income'] == '>50K').astype(int)

# 입력 데이터 분리
X = data.drop("income", axis=1)
y = data["income"]

# 범주형 및 연속형 데이터 분리
X_categ = X[categorical_columns].values
X_cont = X[continuous_columns].values

# 데이터 분할
X_categ_train, X_categ_test, X_cont_train, X_cont_test, y_train, y_test = train_test_split(
    X_categ, X_cont, y, test_size=0.2, random_state=15
)

# %%
# 연속형 데이터 정규화
scaler = StandardScaler()
X_cont_train = scaler.fit_transform(X_cont_train)
X_cont_test = scaler.transform(X_cont_test)

# PyTorch 텐서로 변환
X_categ_train_tensor = torch.tensor(X_categ_train, dtype=torch.long)
X_cont_train_tensor = torch.tensor(X_cont_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train.values, dtype=torch.float32)

X_categ_test_tensor = torch.tensor(X_categ_test, dtype=torch.long)
X_cont_test_tensor = torch.tensor(X_cont_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test.values, dtype=torch.float32)

# %%
# 모델 초기화
model = TabAttention(
    categories=[len(data[col].unique()) for col in categorical_columns],
    num_continuous=len(continuous_columns),
    dim=16,  # 작은 임베딩 차원
    depth=3,  # Transformer 레이어 수 축소
    heads=4,  # Multi-head Attention 수 축소
    dim_head=8,
    dim_out=1,
    mlp_hidden_mults=(2, 1),
    mlp_act=nn.ReLU(),
    attentiontype="col"
)

# %%
# 인코딩 텐서 생성
def create_encodings(x_categ, x_cont, model):
    device = x_categ.device
    x_categ_enc = model.embeds(x_categ + model.categories_offset.to(device))
    x_cont_enc = torch.cat([
        model.simple_MLP[i](x_cont[:, i:i + 1]) for i in range(x_cont.shape[1])
    ], dim=1)
    return x_categ_enc, x_cont_enc

x_categ_train_enc, x_cont_train_enc = create_encodings(X_categ_train_tensor, X_cont_train_tensor, model)
x_categ_test_enc, x_cont_test_enc = create_encodings(X_categ_test_tensor, X_cont_test_tensor, model)

# %%
# 차원 확장 및 크기 맞춤
x_cont_train_enc = x_cont_train_enc.unsqueeze(1).expand(-1, x_categ_train_enc.size(1), -1)
x_cont_test_enc = x_cont_test_enc.unsqueeze(1).expand(-1, x_categ_test_enc.size(1), -1)

# 연속형 임베딩 크기를 카테고리 임베딩 크기와 맞추기
if x_cont_train_enc.size(-1) != x_categ_train_enc.size(-1):
    linear_adjust = nn.Linear(x_cont_train_enc.size(-1), x_categ_train_enc.size(-1))
    x_cont_train_enc = linear_adjust(x_cont_train_enc)
    x_cont_test_enc = linear_adjust(x_cont_test_enc)

# 디버깅: 최종 입력 크기 확인
flat_x_size = (x_categ_train_enc.size(1) * x_categ_train_enc.size(2)) + \
              (x_cont_train_enc.size(1) * x_cont_train_enc.size(2))
print(f"Final flattened input size: {flat_x_size}")

# TabAttention 모델 수정: MLP의 입력 크기 동적으로 설정
model.mlp = nn.Sequential(
    nn.Linear(flat_x_size, 128),  # 첫 번째 레이어의 입력 크기 동적으로 설정
    nn.ReLU(),
    nn.Linear(128, 1)
)
# Out:
# Final flattened input size: 256

# %%
# CPU 설정
device = torch.device("cpu")
model.to(device)

# 손실 함수 및 옵티마이저 정의
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# 디버깅: 모델 크기 확인
print("Model Parameters:")
print(f"Categorical Features: {X_categ_train_tensor.shape}")
print(f"Continuous Features: {X_cont_train_tensor.shape}")
# Out:
# Model Parameters:
# Categorical Features: torch.Size([36177, 8])
# Continuous Features: torch.Size([36177, 6])

# %%
# 학습
epochs = 200
for epoch in range(epochs):
    model.train()
    optimizer.zero_grad()

    # 모델 출력
    outputs = model(X_categ_train_tensor, X_cont_train_tensor, x_categ_train_enc.detach(), x_cont_train_enc.detach()).squeeze()

    # 디버깅: detach()로 그래프에서 분리된 값을 사용
    print(f"Epoch {epoch + 1} - Model Output: Shape = {outputs.shape}, requires_grad = {outputs.requires_grad}")
    
    # 손실 계산
    loss = criterion(outputs, y_train_tensor)
    loss_value = loss.item()  # 손실 값 분리
    print(f"Epoch {epoch + 1} - Loss: {loss_value}, requires_grad = {loss.requires_grad}")

    # 역전파
    loss.backward()  # retain_graph를 사용하지 않도록 기본값 유지
    optimizer.step()

    # 디버깅 출력
    print(f"Epoch {epoch + 1}/{epochs}, Loss: {loss_value}")
# Out:
# Epoch 1 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 1 - Loss: 0.7539287805557251, requires_grad = True
# Epoch 1/200, Loss: 0.7539287805557251
# Epoch 2 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 2 - Loss: 0.6061147451400757, requires_grad = True
# Epoch 2/200, Loss: 0.6061147451400757
# Epoch 3 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 3 - Loss: 0.5457949042320251, requires_grad = True
# Epoch 3/200, Loss: 0.5457949042320251
# Epoch 4 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 4 - Loss: 0.5317996144294739, requires_grad = True
# Epoch 4/200, Loss: 0.5317996144294739
# Epoch 5 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 5 - Loss: 0.528008222579956, requires_grad = True
# Epoch 5/200, Loss: 0.528008222579956
# Epoch 6 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 6 - Loss: 0.5164386034011841, requires_grad = True
# Epoch 6/200, Loss: 0.5164386034011841
# Epoch 7 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 7 - Loss: 0.4948302209377289, requires_grad = True
# Epoch 7/200, Loss: 0.4948302209377289
# Epoch 8 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 8 - Loss: 0.46831604838371277, requires_grad = True
# Epoch 8/200, Loss: 0.46831604838371277
# Epoch 9 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 9 - Loss: 0.4445739686489105, requires_grad = True
# Epoch 9/200, Loss: 0.4445739686489105
# Epoch 10 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 10 - Loss: 0.4306797981262207, requires_grad = True
# Epoch 10/200, Loss: 0.4306797981262207
# Epoch 11 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 11 - Loss: 0.4277861416339874, requires_grad = True
# Epoch 11/200, Loss: 0.4277861416339874
# Epoch 12 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 12 - Loss: 0.4266672134399414, requires_grad = True
# Epoch 12/200, Loss: 0.4266672134399414
# Epoch 13 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 13 - Loss: 0.41839519143104553, requires_grad = True
# Epoch 13/200, Loss: 0.41839519143104553
# Epoch 14 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 14 - Loss: 0.40415725111961365, requires_grad = True
# Epoch 14/200, Loss: 0.40415725111961365
# Epoch 15 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 15 - Loss: 0.3909931480884552, requires_grad = True
# Epoch 15/200, Loss: 0.3909931480884552
# Epoch 16 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 16 - Loss: 0.38433337211608887, requires_grad = True
# Epoch 16/200, Loss: 0.38433337211608887
# Epoch 17 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 17 - Loss: 0.38358259201049805, requires_grad = True
# Epoch 17/200, Loss: 0.38358259201049805
# Epoch 18 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 18 - Loss: 0.38329702615737915, requires_grad = True
# Epoch 18/200, Loss: 0.38329702615737915
# Epoch 19 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 19 - Loss: 0.3790818154811859, requires_grad = True
# Epoch 19/200, Loss: 0.3790818154811859
# Epoch 20 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 20 - Loss: 0.3713996112346649, requires_grad = True
# Epoch 20/200, Loss: 0.3713996112346649
# Epoch 21 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 21 - Loss: 0.36426976323127747, requires_grad = True
# Epoch 21/200, Loss: 0.36426976323127747
# Epoch 22 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 22 - Loss: 0.36126887798309326, requires_grad = True
# Epoch 22/200, Loss: 0.36126887798309326
# Epoch 23 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 23 - Loss: 0.3616955280303955, requires_grad = True
# Epoch 23/200, Loss: 0.3616955280303955
# Epoch 24 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 24 - Loss: 0.3611402213573456, requires_grad = True
# Epoch 24/200, Loss: 0.3611402213573456
# Epoch 25 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 25 - Loss: 0.3571797013282776, requires_grad = True
# Epoch 25/200, Loss: 0.3571797013282776
# Epoch 26 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 26 - Loss: 0.35195115208625793, requires_grad = True
# Epoch 26/200, Loss: 0.35195115208625793
# Epoch 27 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 27 - Loss: 0.34887534379959106, requires_grad = True
# Epoch 27/200, Loss: 0.34887534379959106
# Epoch 28 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 28 - Loss: 0.3485547602176666, requires_grad = True
# Epoch 28/200, Loss: 0.3485547602176666
# Epoch 29 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 29 - Loss: 0.34827277064323425, requires_grad = True
# Epoch 29/200, Loss: 0.34827277064323425
# Epoch 30 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 30 - Loss: 0.345745712518692, requires_grad = True
# Epoch 30/200, Loss: 0.345745712518692
# Epoch 31 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 31 - Loss: 0.3418939411640167, requires_grad = True
# Epoch 31/200, Loss: 0.3418939411640167
# Epoch 32 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 32 - Loss: 0.33930209279060364, requires_grad = True
# Epoch 32/200, Loss: 0.33930209279060364
# Epoch 33 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 33 - Loss: 0.33880287408828735, requires_grad = True
# Epoch 33/200, Loss: 0.33880287408828735
# Epoch 34 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 34 - Loss: 0.338400661945343, requires_grad = True
# Epoch 34/200, Loss: 0.338400661945343
# Epoch 35 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 35 - Loss: 0.33636462688446045, requires_grad = True
# Epoch 35/200, Loss: 0.33636462688446045
# Epoch 36 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 36 - Loss: 0.3337959051132202, requires_grad = True
# Epoch 36/200, Loss: 0.3337959051132202
# Epoch 37 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 37 - Loss: 0.3326610326766968, requires_grad = True
# Epoch 37/200, Loss: 0.3326610326766968
# Epoch 38 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 38 - Loss: 0.33274737000465393, requires_grad = True
# Epoch 38/200, Loss: 0.33274737000465393
# Epoch 39 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 39 - Loss: 0.33226341009140015, requires_grad = True
# Epoch 39/200, Loss: 0.33226341009140015
# Epoch 40 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 40 - Loss: 0.3307873606681824, requires_grad = True
# Epoch 40/200, Loss: 0.3307873606681824
# Epoch 41 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 41 - Loss: 0.3297061026096344, requires_grad = True
# Epoch 41/200, Loss: 0.3297061026096344
# Epoch 42 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 42 - Loss: 0.3297763764858246, requires_grad = True
# Epoch 42/200, Loss: 0.3297763764858246
# Epoch 43 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 43 - Loss: 0.32983124256134033, requires_grad = True
# Epoch 43/200, Loss: 0.32983124256134033
# Epoch 44 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 44 - Loss: 0.3289404511451721, requires_grad = True
# Epoch 44/200, Loss: 0.3289404511451721
# Epoch 45 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 45 - Loss: 0.32801249623298645, requires_grad = True
# Epoch 45/200, Loss: 0.32801249623298645
# Epoch 46 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 46 - Loss: 0.3278452455997467, requires_grad = True
# Epoch 46/200, Loss: 0.3278452455997467
# Epoch 47 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 47 - Loss: 0.3276967704296112, requires_grad = True
# Epoch 47/200, Loss: 0.3276967704296112
# Epoch 48 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 48 - Loss: 0.3268679976463318, requires_grad = True
# Epoch 48/200, Loss: 0.3268679976463318
# Epoch 49 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 49 - Loss: 0.3259618282318115, requires_grad = True
# Epoch 49/200, Loss: 0.3259618282318115
# Epoch 50 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 50 - Loss: 0.3256085515022278, requires_grad = True
# Epoch 50/200, Loss: 0.3256085515022278
# Epoch 51 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 51 - Loss: 0.3253366947174072, requires_grad = True
# Epoch 51/200, Loss: 0.3253366947174072
# Epoch 52 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 52 - Loss: 0.3246397376060486, requires_grad = True
# Epoch 52/200, Loss: 0.3246397376060486
# Epoch 53 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 53 - Loss: 0.32391858100891113, requires_grad = True
# Epoch 53/200, Loss: 0.32391858100891113
# Epoch 54 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 54 - Loss: 0.323593407869339, requires_grad = True
# Epoch 54/200, Loss: 0.323593407869339
# Epoch 55 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 55 - Loss: 0.3233310580253601, requires_grad = True
# Epoch 55/200, Loss: 0.3233310580253601
# Epoch 56 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 56 - Loss: 0.3228040635585785, requires_grad = True
# Epoch 56/200, Loss: 0.3228040635585785
# Epoch 57 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 57 - Loss: 0.32230493426322937, requires_grad = True
# Epoch 57/200, Loss: 0.32230493426322937
# Epoch 58 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 58 - Loss: 0.32208776473999023, requires_grad = True
# Epoch 58/200, Loss: 0.32208776473999023
# Epoch 59 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 59 - Loss: 0.32186412811279297, requires_grad = True
# Epoch 59/200, Loss: 0.32186412811279297
# Epoch 60 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 60 - Loss: 0.3214466869831085, requires_grad = True
# Epoch 60/200, Loss: 0.3214466869831085
# Epoch 61 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 61 - Loss: 0.3211025595664978, requires_grad = True
# Epoch 61/200, Loss: 0.3211025595664978
# Epoch 62 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 62 - Loss: 0.32092997431755066, requires_grad = True
# Epoch 62/200, Loss: 0.32092997431755066
# Epoch 63 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 63 - Loss: 0.3206636905670166, requires_grad = True
# Epoch 63/200, Loss: 0.3206636905670166
# Epoch 64 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 64 - Loss: 0.3202775716781616, requires_grad = True
# Epoch 64/200, Loss: 0.3202775716781616
# Epoch 65 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 65 - Loss: 0.31999990344047546, requires_grad = True
# Epoch 65/200, Loss: 0.31999990344047546
# Epoch 66 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 66 - Loss: 0.3197938799858093, requires_grad = True
# Epoch 66/200, Loss: 0.3197938799858093
# Epoch 67 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 67 - Loss: 0.31948187947273254, requires_grad = True
# Epoch 67/200, Loss: 0.31948187947273254
# Epoch 68 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 68 - Loss: 0.3191608190536499, requires_grad = True
# Epoch 68/200, Loss: 0.3191608190536499
# Epoch 69 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 69 - Loss: 0.31895193457603455, requires_grad = True
# Epoch 69/200, Loss: 0.31895193457603455
# Epoch 70 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 70 - Loss: 0.3187313973903656, requires_grad = True
# Epoch 70/200, Loss: 0.3187313973903656
# Epoch 71 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 71 - Loss: 0.3184409439563751, requires_grad = True
# Epoch 71/200, Loss: 0.3184409439563751
# Epoch 72 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 72 - Loss: 0.3182014524936676, requires_grad = True
# Epoch 72/200, Loss: 0.3182014524936676
# Epoch 73 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 73 - Loss: 0.3180088698863983, requires_grad = True
# Epoch 73/200, Loss: 0.3180088698863983
# Epoch 74 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 74 - Loss: 0.31776005029678345, requires_grad = True
# Epoch 74/200, Loss: 0.31776005029678345
# Epoch 75 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 75 - Loss: 0.3175089657306671, requires_grad = True
# Epoch 75/200, Loss: 0.3175089657306671
# Epoch 76 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 76 - Loss: 0.3173177242279053, requires_grad = True
# Epoch 76/200, Loss: 0.3173177242279053
# Epoch 77 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 77 - Loss: 0.31710416078567505, requires_grad = True
# Epoch 77/200, Loss: 0.31710416078567505
# Epoch 78 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 78 - Loss: 0.3168638050556183, requires_grad = True
# Epoch 78/200, Loss: 0.3168638050556183
# Epoch 79 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 79 - Loss: 0.316665381193161, requires_grad = True
# Epoch 79/200, Loss: 0.316665381193161
# Epoch 80 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 80 - Loss: 0.31646570563316345, requires_grad = True
# Epoch 80/200, Loss: 0.31646570563316345
# Epoch 81 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 81 - Loss: 0.31623518466949463, requires_grad = True
# Epoch 81/200, Loss: 0.31623518466949463
# Epoch 82 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 82 - Loss: 0.3160305917263031, requires_grad = True
# Epoch 82/200, Loss: 0.3160305917263031
# Epoch 83 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 83 - Loss: 0.31583279371261597, requires_grad = True
# Epoch 83/200, Loss: 0.31583279371261597
# Epoch 84 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 84 - Loss: 0.315609872341156, requires_grad = True
# Epoch 84/200, Loss: 0.315609872341156
# Epoch 85 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 85 - Loss: 0.31540533900260925, requires_grad = True
# Epoch 85/200, Loss: 0.31540533900260925
# Epoch 86 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 86 - Loss: 0.3152127265930176, requires_grad = True
# Epoch 86/200, Loss: 0.3152127265930176
# Epoch 87 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 87 - Loss: 0.31500208377838135, requires_grad = True
# Epoch 87/200, Loss: 0.31500208377838135
# Epoch 88 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 88 - Loss: 0.3148026168346405, requires_grad = True
# Epoch 88/200, Loss: 0.3148026168346405
# Epoch 89 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 89 - Loss: 0.31461164355278015, requires_grad = True
# Epoch 89/200, Loss: 0.31461164355278015
# Epoch 90 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 90 - Loss: 0.3144092857837677, requires_grad = True
# Epoch 90/200, Loss: 0.3144092857837677
# Epoch 91 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 91 - Loss: 0.31421950459480286, requires_grad = True
# Epoch 91/200, Loss: 0.31421950459480286
# Epoch 92 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 92 - Loss: 0.31403791904449463, requires_grad = True
# Epoch 92/200, Loss: 0.31403791904449463
# Epoch 93 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 93 - Loss: 0.31384748220443726, requires_grad = True
# Epoch 93/200, Loss: 0.31384748220443726
# Epoch 94 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 94 - Loss: 0.31366628408432007, requires_grad = True
# Epoch 94/200, Loss: 0.31366628408432007
# Epoch 95 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 95 - Loss: 0.31348660588264465, requires_grad = True
# Epoch 95/200, Loss: 0.31348660588264465
# Epoch 96 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 96 - Loss: 0.31330034136772156, requires_grad = True
# Epoch 96/200, Loss: 0.31330034136772156
# Epoch 97 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 97 - Loss: 0.31312260031700134, requires_grad = True
# Epoch 97/200, Loss: 0.31312260031700134
# Epoch 98 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 98 - Loss: 0.31294214725494385, requires_grad = True
# Epoch 98/200, Loss: 0.31294214725494385
# Epoch 99 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 99 - Loss: 0.3127595782279968, requires_grad = True
# Epoch 99/200, Loss: 0.3127595782279968
# Epoch 100 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 100 - Loss: 0.3125840127468109, requires_grad = True
# Epoch 100/200, Loss: 0.3125840127468109
# Epoch 101 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 101 - Loss: 0.3124036192893982, requires_grad = True
# Epoch 101/200, Loss: 0.3124036192893982
# Epoch 102 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 102 - Loss: 0.3122262954711914, requires_grad = True
# Epoch 102/200, Loss: 0.3122262954711914
# Epoch 103 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 103 - Loss: 0.31205081939697266, requires_grad = True
# Epoch 103/200, Loss: 0.31205081939697266
# Epoch 104 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 104 - Loss: 0.3118723928928375, requires_grad = True
# Epoch 104/200, Loss: 0.3118723928928375
# Epoch 105 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 105 - Loss: 0.31169891357421875, requires_grad = True
# Epoch 105/200, Loss: 0.31169891357421875
# Epoch 106 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 106 - Loss: 0.3115256726741791, requires_grad = True
# Epoch 106/200, Loss: 0.3115256726741791
# Epoch 107 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 107 - Loss: 0.31135258078575134, requires_grad = True
# Epoch 107/200, Loss: 0.31135258078575134
# Epoch 108 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 108 - Loss: 0.3111826479434967, requires_grad = True
# Epoch 108/200, Loss: 0.3111826479434967
# Epoch 109 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 109 - Loss: 0.31101083755493164, requires_grad = True
# Epoch 109/200, Loss: 0.31101083755493164
# Epoch 110 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 110 - Loss: 0.31084251403808594, requires_grad = True
# Epoch 110/200, Loss: 0.31084251403808594
# Epoch 111 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 111 - Loss: 0.3106748163700104, requires_grad = True
# Epoch 111/200, Loss: 0.3106748163700104
# Epoch 112 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 112 - Loss: 0.31050798296928406, requires_grad = True
# Epoch 112/200, Loss: 0.31050798296928406
# Epoch 113 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 113 - Loss: 0.31034430861473083, requires_grad = True
# Epoch 113/200, Loss: 0.31034430861473083
# Epoch 114 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 114 - Loss: 0.3101803958415985, requires_grad = True
# Epoch 114/200, Loss: 0.3101803958415985
# Epoch 115 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 115 - Loss: 0.31001922488212585, requires_grad = True
# Epoch 115/200, Loss: 0.31001922488212585
# Epoch 116 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 116 - Loss: 0.309858113527298, requires_grad = True
# Epoch 116/200, Loss: 0.309858113527298
# Epoch 117 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 117 - Loss: 0.309698224067688, requires_grad = True
# Epoch 117/200, Loss: 0.309698224067688
# Epoch 118 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 118 - Loss: 0.3095402121543884, requires_grad = True
# Epoch 118/200, Loss: 0.3095402121543884
# Epoch 119 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 119 - Loss: 0.309382826089859, requires_grad = True
# Epoch 119/200, Loss: 0.309382826089859
# Epoch 120 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 120 - Loss: 0.30922847986221313, requires_grad = True
# Epoch 120/200, Loss: 0.30922847986221313
# Epoch 121 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 121 - Loss: 0.3090759217739105, requires_grad = True
# Epoch 121/200, Loss: 0.3090759217739105
# Epoch 122 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 122 - Loss: 0.3089260756969452, requires_grad = True
# Epoch 122/200, Loss: 0.3089260756969452
# Epoch 123 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 123 - Loss: 0.3087770640850067, requires_grad = True
# Epoch 123/200, Loss: 0.3087770640850067
# Epoch 124 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 124 - Loss: 0.30862951278686523, requires_grad = True
# Epoch 124/200, Loss: 0.30862951278686523
# Epoch 125 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 125 - Loss: 0.3084820508956909, requires_grad = True
# Epoch 125/200, Loss: 0.3084820508956909
# Epoch 126 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 126 - Loss: 0.3083362579345703, requires_grad = True
# Epoch 126/200, Loss: 0.3083362579345703
# Epoch 127 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 127 - Loss: 0.308192640542984, requires_grad = True
# Epoch 127/200, Loss: 0.308192640542984
# Epoch 128 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 128 - Loss: 0.3080504238605499, requires_grad = True
# Epoch 128/200, Loss: 0.3080504238605499
# Epoch 129 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 129 - Loss: 0.3079092502593994, requires_grad = True
# Epoch 129/200, Loss: 0.3079092502593994
# Epoch 130 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 130 - Loss: 0.30776968598365784, requires_grad = True
# Epoch 130/200, Loss: 0.30776968598365784
# Epoch 131 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 131 - Loss: 0.30763205885887146, requires_grad = True
# Epoch 131/200, Loss: 0.30763205885887146
# Epoch 132 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 132 - Loss: 0.3074963390827179, requires_grad = True
# Epoch 132/200, Loss: 0.3074963390827179
# Epoch 133 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 133 - Loss: 0.30736222863197327, requires_grad = True
# Epoch 133/200, Loss: 0.30736222863197327
# Epoch 134 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 134 - Loss: 0.307230144739151, requires_grad = True
# Epoch 134/200, Loss: 0.307230144739151
# Epoch 135 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 135 - Loss: 0.3070988655090332, requires_grad = True
# Epoch 135/200, Loss: 0.3070988655090332
# Epoch 136 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 136 - Loss: 0.30696940422058105, requires_grad = True
# Epoch 136/200, Loss: 0.30696940422058105
# Epoch 137 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 137 - Loss: 0.3068414032459259, requires_grad = True
# Epoch 137/200, Loss: 0.3068414032459259
# Epoch 138 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 138 - Loss: 0.30671414732933044, requires_grad = True
# Epoch 138/200, Loss: 0.30671414732933044
# Epoch 139 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 139 - Loss: 0.30658766627311707, requires_grad = True
# Epoch 139/200, Loss: 0.30658766627311707
# Epoch 140 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 140 - Loss: 0.30646300315856934, requires_grad = True
# Epoch 140/200, Loss: 0.30646300315856934
# Epoch 141 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 141 - Loss: 0.3063391149044037, requires_grad = True
# Epoch 141/200, Loss: 0.3063391149044037
# Epoch 142 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 142 - Loss: 0.3062167465686798, requires_grad = True
# Epoch 142/200, Loss: 0.3062167465686798
# Epoch 143 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 143 - Loss: 0.30609554052352905, requires_grad = True
# Epoch 143/200, Loss: 0.30609554052352905
# Epoch 144 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 144 - Loss: 0.30597496032714844, requires_grad = True
# Epoch 144/200, Loss: 0.30597496032714844
# Epoch 145 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 145 - Loss: 0.3058544993400574, requires_grad = True
# Epoch 145/200, Loss: 0.3058544993400574
# Epoch 146 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 146 - Loss: 0.30573388934135437, requires_grad = True
# Epoch 146/200, Loss: 0.30573388934135437
# Epoch 147 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 147 - Loss: 0.3056138753890991, requires_grad = True
# Epoch 147/200, Loss: 0.3056138753890991
# Epoch 148 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 148 - Loss: 0.30549538135528564, requires_grad = True
# Epoch 148/200, Loss: 0.30549538135528564
# Epoch 149 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 149 - Loss: 0.30537742376327515, requires_grad = True
# Epoch 149/200, Loss: 0.30537742376327515
# Epoch 150 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 150 - Loss: 0.3052596151828766, requires_grad = True
# Epoch 150/200, Loss: 0.3052596151828766
# Epoch 151 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 151 - Loss: 0.3051423728466034, requires_grad = True
# Epoch 151/200, Loss: 0.3051423728466034
# Epoch 152 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 152 - Loss: 0.3050249218940735, requires_grad = True
# Epoch 152/200, Loss: 0.3050249218940735
# Epoch 153 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 153 - Loss: 0.3049079477787018, requires_grad = True
# Epoch 153/200, Loss: 0.3049079477787018
# Epoch 154 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 154 - Loss: 0.30479151010513306, requires_grad = True
# Epoch 154/200, Loss: 0.30479151010513306
# Epoch 155 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 155 - Loss: 0.3046765923500061, requires_grad = True
# Epoch 155/200, Loss: 0.3046765923500061
# Epoch 156 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 156 - Loss: 0.30456238985061646, requires_grad = True
# Epoch 156/200, Loss: 0.30456238985061646
# Epoch 157 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 157 - Loss: 0.304448664188385, requires_grad = True
# Epoch 157/200, Loss: 0.304448664188385
# Epoch 158 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 158 - Loss: 0.3043351173400879, requires_grad = True
# Epoch 158/200, Loss: 0.3043351173400879
# Epoch 159 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 159 - Loss: 0.3042210340499878, requires_grad = True
# Epoch 159/200, Loss: 0.3042210340499878
# Epoch 160 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 160 - Loss: 0.30410754680633545, requires_grad = True
# Epoch 160/200, Loss: 0.30410754680633545
# Epoch 161 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 161 - Loss: 0.30399495363235474, requires_grad = True
# Epoch 161/200, Loss: 0.30399495363235474
# Epoch 162 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 162 - Loss: 0.30388227105140686, requires_grad = True
# Epoch 162/200, Loss: 0.30388227105140686
# Epoch 163 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 163 - Loss: 0.30376991629600525, requires_grad = True
# Epoch 163/200, Loss: 0.30376991629600525
# Epoch 164 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 164 - Loss: 0.3036578297615051, requires_grad = True
# Epoch 164/200, Loss: 0.3036578297615051
# Epoch 165 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 165 - Loss: 0.30354535579681396, requires_grad = True
# Epoch 165/200, Loss: 0.30354535579681396
# Epoch 166 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 166 - Loss: 0.30343273282051086, requires_grad = True
# Epoch 166/200, Loss: 0.30343273282051086
# Epoch 167 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 167 - Loss: 0.303320050239563, requires_grad = True
# Epoch 167/200, Loss: 0.303320050239563
# Epoch 168 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 168 - Loss: 0.30320748686790466, requires_grad = True
# Epoch 168/200, Loss: 0.30320748686790466
# Epoch 169 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 169 - Loss: 0.303094744682312, requires_grad = True
# Epoch 169/200, Loss: 0.303094744682312
# Epoch 170 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 170 - Loss: 0.30298179388046265, requires_grad = True
# Epoch 170/200, Loss: 0.30298179388046265
# Epoch 171 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 171 - Loss: 0.30286869406700134, requires_grad = True
# Epoch 171/200, Loss: 0.30286869406700134
# Epoch 172 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 172 - Loss: 0.302755206823349, requires_grad = True
# Epoch 172/200, Loss: 0.302755206823349
# Epoch 173 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 173 - Loss: 0.30264145135879517, requires_grad = True
# Epoch 173/200, Loss: 0.30264145135879517
# Epoch 174 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 174 - Loss: 0.3025282621383667, requires_grad = True
# Epoch 174/200, Loss: 0.3025282621383667
# Epoch 175 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 175 - Loss: 0.3024147152900696, requires_grad = True
# Epoch 175/200, Loss: 0.3024147152900696
# Epoch 176 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 176 - Loss: 0.30229952931404114, requires_grad = True
# Epoch 176/200, Loss: 0.30229952931404114
# Epoch 177 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 177 - Loss: 0.30218422412872314, requires_grad = True
# Epoch 177/200, Loss: 0.30218422412872314
# Epoch 178 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 178 - Loss: 0.3020697236061096, requires_grad = True
# Epoch 178/200, Loss: 0.3020697236061096
# Epoch 179 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 179 - Loss: 0.3019547462463379, requires_grad = True
# Epoch 179/200, Loss: 0.3019547462463379
# Epoch 180 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 180 - Loss: 0.30184033513069153, requires_grad = True
# Epoch 180/200, Loss: 0.30184033513069153
# Epoch 181 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 181 - Loss: 0.3017246425151825, requires_grad = True
# Epoch 181/200, Loss: 0.3017246425151825
# Epoch 182 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 182 - Loss: 0.3016093671321869, requires_grad = True
# Epoch 182/200, Loss: 0.3016093671321869
# Epoch 183 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 183 - Loss: 0.3014938533306122, requires_grad = True
# Epoch 183/200, Loss: 0.3014938533306122
# Epoch 184 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 184 - Loss: 0.3013789653778076, requires_grad = True
# Epoch 184/200, Loss: 0.3013789653778076
# Epoch 185 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 185 - Loss: 0.30126404762268066, requires_grad = True
# Epoch 185/200, Loss: 0.30126404762268066
# Epoch 186 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 186 - Loss: 0.3011491298675537, requires_grad = True
# Epoch 186/200, Loss: 0.3011491298675537
# Epoch 187 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 187 - Loss: 0.30103376507759094, requires_grad = True
# Epoch 187/200, Loss: 0.30103376507759094
# Epoch 188 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 188 - Loss: 0.3009181618690491, requires_grad = True
# Epoch 188/200, Loss: 0.3009181618690491
# Epoch 189 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 189 - Loss: 0.3008023798465729, requires_grad = True
# Epoch 189/200, Loss: 0.3008023798465729
# Epoch 190 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 190 - Loss: 0.3006863296031952, requires_grad = True
# Epoch 190/200, Loss: 0.3006863296031952
# Epoch 191 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 191 - Loss: 0.30057135224342346, requires_grad = True
# Epoch 191/200, Loss: 0.30057135224342346
# Epoch 192 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 192 - Loss: 0.3004571199417114, requires_grad = True
# Epoch 192/200, Loss: 0.3004571199417114
# Epoch 193 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 193 - Loss: 0.3003428280353546, requires_grad = True
# Epoch 193/200, Loss: 0.3003428280353546
# Epoch 194 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 194 - Loss: 0.3002288341522217, requires_grad = True
# Epoch 194/200, Loss: 0.3002288341522217
# Epoch 195 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 195 - Loss: 0.3001139461994171, requires_grad = True
# Epoch 195/200, Loss: 0.3001139461994171
# Epoch 196 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 196 - Loss: 0.2999981939792633, requires_grad = True
# Epoch 196/200, Loss: 0.2999981939792633
# Epoch 197 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 197 - Loss: 0.29987987875938416, requires_grad = True
# Epoch 197/200, Loss: 0.29987987875938416
# Epoch 198 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 198 - Loss: 0.29976069927215576, requires_grad = True
# Epoch 198/200, Loss: 0.29976069927215576
# Epoch 199 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 199 - Loss: 0.29964086413383484, requires_grad = True
# Epoch 199/200, Loss: 0.29964086413383484
# Epoch 200 - Model Output: Shape = torch.Size([36177]), requires_grad = True
# Epoch 200 - Loss: 0.2995219826698303, requires_grad = True
# Epoch 200/200, Loss: 0.2995219826698303

# %%
from sklearn.metrics import confusion_matrix

# 평가
model.eval()
with torch.no_grad():
    predictions = model(X_categ_test_tensor, X_cont_test_tensor, x_categ_test_enc, x_cont_test_enc).squeeze()
    predictions = torch.sigmoid(predictions).cpu().numpy()
    pred_labels = (predictions > 0.5).astype(int)

    # 성능 지표 계산
    accuracy = accuracy_score(y_test, pred_labels)
    auroc = roc_auc_score(y_test, predictions)
    precision = precision_score(y_test, pred_labels)
    recall = recall_score(y_test, pred_labels)
    f1 = f1_score(y_test, pred_labels)

    # 공정성 지표 계산
    sensitive_attr = X_categ_test_tensor[:, categorical_columns.index('gender')].cpu().numpy()  # gender 컬럼
    group_0 = sensitive_attr == 0  # 예: 남성
    group_1 = sensitive_attr == 1  # 예: 여성

    # Demographic Parity
    dp = abs(pred_labels[group_0].mean() - pred_labels[group_1].mean())

    # Equal Opportunity
    eo = abs(pred_labels[group_0 & (y_test == 1)].mean() - pred_labels[group_1 & (y_test == 1)].mean())

    # Equality of Odds
    group_0_tpr = pred_labels[group_0 & (y_test == 1)].mean()
    group_1_tpr = pred_labels[group_1 & (y_test == 1)].mean()
    group_0_fpr = pred_labels[group_0 & (y_test == 0)].mean()
    group_1_fpr = pred_labels[group_1 & (y_test == 0)].mean()
    eop = abs(group_0_tpr - group_1_tpr) + abs(group_0_fpr - group_1_fpr)

# 평가 결과 출력
print("\n모델 평가 결과:")
print(f"정확도 (Accuracy): {accuracy:.4f}")
print(f"AUROC: {auroc:.4f}")
print(f"정밀도 (Precision): {precision:.4f}")
print(f"재현율 (Recall): {recall:.4f}")
print(f"F1 점수 (F1-Score): {f1:.4f}")

# 공정성 지표 출력
print("\n공정성 지표:")
print(f"Demographic Parity (DP): {dp:.4f}")
print(f"Equal Opportunity (EO): {eo:.4f}")
print(f"Equality of Odds (EOP): {eop:.4f}")
# Out:
# 모델 평가 결과:
# 정확도 (Accuracy): 0.8585
# AUROC: 0.9129
# 정밀도 (Precision): 0.7673
# 재현율 (Recall): 0.6110
# F1 점수 (F1-Score): 0.6803
#
# 공정성 지표:
# Demographic Parity (DP): 0.1668
# Equal Opportunity (EO): 0.0503
# Equality of Odds (EOP): 0.1173
