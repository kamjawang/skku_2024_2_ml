# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score, roc_auc_score, precision_score, recall_score, f1_score
import torch
import torch.nn as nn
import torch.optim as optim
import sys
sys.path.append("F:/기계학습특론/saint-main/models")  # SAINT 경로 추가
from model import TabAttention  # model.py에서 TabAttention 클래스 임포트

# 데이터 로드 및 전처리
file_path = "income_evaluation.csv"
data = pd.read_csv(file_path)

# %%
# 열 이름의 공백 제거
data.columns = data.columns.str.strip()

# '?' 처리 및 결측치 제거
data.replace('?', pd.NA, inplace=True)
data.dropna(inplace=True)

# income 열 공백 제거 후 타겟 데이터 인코딩
data['income'] = data['income'].astype(str).str.strip()
data['income'] = (data['income'] == '>50K').astype(int)

# 범주형 데이터와 연속형 데이터 구분
categorical_columns = [
    'workclass', 'education', 'marital-status', 'occupation',
    'relationship', 'race', 'sex', 'native-country'
]
continuous_columns = [
    'age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week'
]

# %%
# 범주형 데이터 인코딩
label_encoders = {col: LabelEncoder().fit(data[col]) for col in categorical_columns}
for col, encoder in label_encoders.items():
    data[col] = encoder.transform(data[col])

# 입력 데이터 분리
X = data.drop("income", axis=1)
y = data["income"]

# 범주형 및 연속형 데이터 분리
X_categ = X[categorical_columns].values
X_cont = X[continuous_columns].values

# 데이터 분할
X_categ_train, X_categ_test, X_cont_train, X_cont_test, y_train, y_test = train_test_split(
    X_categ, X_cont, y, test_size=0.2, random_state=15
)

# %%
# 연속형 데이터 정규화
scaler = StandardScaler()
X_cont_train = scaler.fit_transform(X_cont_train)
X_cont_test = scaler.transform(X_cont_test)

# PyTorch 텐서로 변환
X_categ_train_tensor = torch.tensor(X_categ_train, dtype=torch.long)
X_cont_train_tensor = torch.tensor(X_cont_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train.values, dtype=torch.float32)

X_categ_test_tensor = torch.tensor(X_categ_test, dtype=torch.long)
X_cont_test_tensor = torch.tensor(X_cont_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test.values, dtype=torch.float32)

# %%
# 모델 초기화
model = TabAttention(
    categories=[len(data[col].unique()) for col in categorical_columns],
    num_continuous=len(continuous_columns),
    dim=16,
    depth=3,
    heads=4,
    dim_head=8,
    dim_out=1,
    mlp_hidden_mults=(2, 1),
    mlp_act=nn.ReLU(),
    attentiontype="col"
)

# %%
# 인코딩 텐서 생성
def create_encodings(x_categ, x_cont, model):
    device = x_categ.device
    x_categ_enc = model.embeds(x_categ + model.categories_offset.to(device))
    x_cont_enc = torch.cat([
        model.simple_MLP[i](x_cont[:, i:i + 1]) for i in range(x_cont.shape[1])
    ], dim=1)
    return x_categ_enc, x_cont_enc

x_categ_train_enc, x_cont_train_enc = create_encodings(X_categ_train_tensor, X_cont_train_tensor, model)
x_categ_test_enc, x_cont_test_enc = create_encodings(X_categ_test_tensor, X_cont_test_tensor, model)

# %%
# 차원 확장 및 크기 맞춤
x_cont_train_enc = x_cont_train_enc.unsqueeze(1).expand(-1, x_categ_train_enc.size(1), -1)
x_cont_test_enc = x_cont_test_enc.unsqueeze(1).expand(-1, x_categ_test_enc.size(1), -1)

# 연속형 임베딩 크기를 카테고리 임베딩 크기와 맞추기
if x_cont_train_enc.size(-1) != x_categ_train_enc.size(-1):
    linear_adjust = nn.Linear(x_cont_train_enc.size(-1), x_categ_train_enc.size(-1))
    x_cont_train_enc = linear_adjust(x_cont_train_enc)
    x_cont_test_enc = linear_adjust(x_cont_test_enc)

# 디버깅: 최종 입력 크기 확인
flat_x_size = (x_categ_train_enc.size(1) * x_categ_train_enc.size(2)) + \
              (x_cont_train_enc.size(1) * x_cont_train_enc.size(2))
print(f"Final flattened input size: {flat_x_size}")

# TabAttention 모델 수정: MLP의 입력 크기 동적으로 설정
model.mlp = nn.Sequential(
    nn.Linear(flat_x_size, 128),  # 첫 번째 레이어의 입력 크기 동적으로 설정
    nn.ReLU(),
    nn.Linear(128, 1)
)
# Out:
# Final flattened input size: 256

# %%
# CPU 설정
device = torch.device("cpu")
model.to(device)

# 손실 함수 및 옵티마이저 정의
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# 디버깅: 모델 크기 확인
print("Model Parameters:")
print(f"Categorical Features: {X_categ_train_tensor.shape}")
print(f"Continuous Features: {X_cont_train_tensor.shape}")
# Out:
# Model Parameters:
# Categorical Features: torch.Size([26048, 8])
# Continuous Features: torch.Size([26048, 6])

# %%
# 학습
epochs = 100
for epoch in range(epochs):
    model.train()
    optimizer.zero_grad()

    # 모델 출력
    outputs = model(X_categ_train_tensor, X_cont_train_tensor, x_categ_train_enc.detach(), x_cont_train_enc.detach()).squeeze()

    # 디버깅: detach()로 그래프에서 분리된 값을 사용
    print(f"Epoch {epoch + 1} - Model Output: Shape = {outputs.shape}, requires_grad = {outputs.requires_grad}")
    
    # 손실 계산
    loss = criterion(outputs, y_train_tensor)
    loss_value = loss.item()  # 손실 값 분리
    print(f"Epoch {epoch + 1} - Loss: {loss_value}, requires_grad = {loss.requires_grad}")

    # 역전파
    loss.backward()  # retain_graph를 사용하지 않도록 기본값 유지
    optimizer.step()

    # 디버깅 출력
    print(f"Epoch {epoch + 1}/{epochs}, Loss: {loss_value}")
# Out:
# Epoch 1 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 1 - Loss: 0.6510041952133179, requires_grad = True
# Epoch 1/100, Loss: 0.6510041952133179
# Epoch 2 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 2 - Loss: 0.5667709708213806, requires_grad = True
# Epoch 2/100, Loss: 0.5667709708213806
# Epoch 3 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 3 - Loss: 0.5217235684394836, requires_grad = True
# Epoch 3/100, Loss: 0.5217235684394836
# Epoch 4 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 4 - Loss: 0.49616536498069763, requires_grad = True
# Epoch 4/100, Loss: 0.49616536498069763
# Epoch 5 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 5 - Loss: 0.4750957787036896, requires_grad = True
# Epoch 5/100, Loss: 0.4750957787036896
# Epoch 6 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 6 - Loss: 0.45265620946884155, requires_grad = True
# Epoch 6/100, Loss: 0.45265620946884155
# Epoch 7 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 7 - Loss: 0.4309045970439911, requires_grad = True
# Epoch 7/100, Loss: 0.4309045970439911
# Epoch 8 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 8 - Loss: 0.41424256563186646, requires_grad = True
# Epoch 8/100, Loss: 0.41424256563186646
# Epoch 9 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 9 - Loss: 0.40424445271492004, requires_grad = True
# Epoch 9/100, Loss: 0.40424445271492004
# Epoch 10 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 10 - Loss: 0.3972327411174774, requires_grad = True
# Epoch 10/100, Loss: 0.3972327411174774
# Epoch 11 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 11 - Loss: 0.38842782378196716, requires_grad = True
# Epoch 11/100, Loss: 0.38842782378196716
# Epoch 12 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 12 - Loss: 0.3776993453502655, requires_grad = True
# Epoch 12/100, Loss: 0.3776993453502655
# Epoch 13 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 13 - Loss: 0.3682360053062439, requires_grad = True
# Epoch 13/100, Loss: 0.3682360053062439
# Epoch 14 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 14 - Loss: 0.36246585845947266, requires_grad = True
# Epoch 14/100, Loss: 0.36246585845947266
# Epoch 15 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 15 - Loss: 0.3593534827232361, requires_grad = True
# Epoch 15/100, Loss: 0.3593534827232361
# Epoch 16 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 16 - Loss: 0.3560299575328827, requires_grad = True
# Epoch 16/100, Loss: 0.3560299575328827
# Epoch 17 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 17 - Loss: 0.3518812358379364, requires_grad = True
# Epoch 17/100, Loss: 0.3518812358379364
# Epoch 18 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 18 - Loss: 0.34883424639701843, requires_grad = True
# Epoch 18/100, Loss: 0.34883424639701843
# Epoch 19 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 19 - Loss: 0.3477312922477722, requires_grad = True
# Epoch 19/100, Loss: 0.3477312922477722
# Epoch 20 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 20 - Loss: 0.3464049994945526, requires_grad = True
# Epoch 20/100, Loss: 0.3464049994945526
# Epoch 21 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 21 - Loss: 0.3431411385536194, requires_grad = True
# Epoch 21/100, Loss: 0.3431411385536194
# Epoch 22 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 22 - Loss: 0.3394169509410858, requires_grad = True
# Epoch 22/100, Loss: 0.3394169509410858
# Epoch 23 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 23 - Loss: 0.3371521234512329, requires_grad = True
# Epoch 23/100, Loss: 0.3371521234512329
# Epoch 24 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 24 - Loss: 0.3355269134044647, requires_grad = True
# Epoch 24/100, Loss: 0.3355269134044647
# Epoch 25 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 25 - Loss: 0.3330199122428894, requires_grad = True
# Epoch 25/100, Loss: 0.3330199122428894
# Epoch 26 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 26 - Loss: 0.3306848406791687, requires_grad = True
# Epoch 26/100, Loss: 0.3306848406791687
# Epoch 27 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 27 - Loss: 0.3297244608402252, requires_grad = True
# Epoch 27/100, Loss: 0.3297244608402252
# Epoch 28 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 28 - Loss: 0.3286716043949127, requires_grad = True
# Epoch 28/100, Loss: 0.3286716043949127
# Epoch 29 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 29 - Loss: 0.32660120725631714, requires_grad = True
# Epoch 29/100, Loss: 0.32660120725631714
# Epoch 30 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 30 - Loss: 0.32512545585632324, requires_grad = True
# Epoch 30/100, Loss: 0.32512545585632324
# Epoch 31 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 31 - Loss: 0.32463717460632324, requires_grad = True
# Epoch 31/100, Loss: 0.32463717460632324
# Epoch 32 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 32 - Loss: 0.3236473798751831, requires_grad = True
# Epoch 32/100, Loss: 0.3236473798751831
# Epoch 33 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 33 - Loss: 0.32250508666038513, requires_grad = True
# Epoch 33/100, Loss: 0.32250508666038513
# Epoch 34 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 34 - Loss: 0.3221268355846405, requires_grad = True
# Epoch 34/100, Loss: 0.3221268355846405
# Epoch 35 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 35 - Loss: 0.3213983476161957, requires_grad = True
# Epoch 35/100, Loss: 0.3213983476161957
# Epoch 36 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 36 - Loss: 0.32005542516708374, requires_grad = True
# Epoch 36/100, Loss: 0.32005542516708374
# Epoch 37 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 37 - Loss: 0.31924018263816833, requires_grad = True
# Epoch 37/100, Loss: 0.31924018263816833
# Epoch 38 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 38 - Loss: 0.31867074966430664, requires_grad = True
# Epoch 38/100, Loss: 0.31867074966430664
# Epoch 39 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 39 - Loss: 0.31774193048477173, requires_grad = True
# Epoch 39/100, Loss: 0.31774193048477173
# Epoch 40 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 40 - Loss: 0.31704652309417725, requires_grad = True
# Epoch 40/100, Loss: 0.31704652309417725
# Epoch 41 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 41 - Loss: 0.3166126310825348, requires_grad = True
# Epoch 41/100, Loss: 0.3166126310825348
# Epoch 42 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 42 - Loss: 0.3158595860004425, requires_grad = True
# Epoch 42/100, Loss: 0.3158595860004425
# Epoch 43 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 43 - Loss: 0.3151209354400635, requires_grad = True
# Epoch 43/100, Loss: 0.3151209354400635
# Epoch 44 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 44 - Loss: 0.31473270058631897, requires_grad = True
# Epoch 44/100, Loss: 0.31473270058631897
# Epoch 45 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 45 - Loss: 0.3142678439617157, requires_grad = True
# Epoch 45/100, Loss: 0.3142678439617157
# Epoch 46 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 46 - Loss: 0.31371763348579407, requires_grad = True
# Epoch 46/100, Loss: 0.31371763348579407
# Epoch 47 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 47 - Loss: 0.31335678696632385, requires_grad = True
# Epoch 47/100, Loss: 0.31335678696632385
# Epoch 48 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 48 - Loss: 0.3129178285598755, requires_grad = True
# Epoch 48/100, Loss: 0.3129178285598755
# Epoch 49 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 49 - Loss: 0.3123307526111603, requires_grad = True
# Epoch 49/100, Loss: 0.3123307526111603
# Epoch 50 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 50 - Loss: 0.3119202256202698, requires_grad = True
# Epoch 50/100, Loss: 0.3119202256202698
# Epoch 51 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 51 - Loss: 0.3115515112876892, requires_grad = True
# Epoch 51/100, Loss: 0.3115515112876892
# Epoch 52 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 52 - Loss: 0.3110896944999695, requires_grad = True
# Epoch 52/100, Loss: 0.3110896944999695
# Epoch 53 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 53 - Loss: 0.31074100732803345, requires_grad = True
# Epoch 53/100, Loss: 0.31074100732803345
# Epoch 54 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 54 - Loss: 0.3103848695755005, requires_grad = True
# Epoch 54/100, Loss: 0.3103848695755005
# Epoch 55 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 55 - Loss: 0.3099566102027893, requires_grad = True
# Epoch 55/100, Loss: 0.3099566102027893
# Epoch 56 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 56 - Loss: 0.30965885519981384, requires_grad = True
# Epoch 56/100, Loss: 0.30965885519981384
# Epoch 57 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 57 - Loss: 0.3093642294406891, requires_grad = True
# Epoch 57/100, Loss: 0.3093642294406891
# Epoch 58 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 58 - Loss: 0.30903416872024536, requires_grad = True
# Epoch 58/100, Loss: 0.30903416872024536
# Epoch 59 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 59 - Loss: 0.30877557396888733, requires_grad = True
# Epoch 59/100, Loss: 0.30877557396888733
# Epoch 60 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 60 - Loss: 0.3084588646888733, requires_grad = True
# Epoch 60/100, Loss: 0.3084588646888733
# Epoch 61 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 61 - Loss: 0.30814528465270996, requires_grad = True
# Epoch 61/100, Loss: 0.30814528465270996
# Epoch 62 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 62 - Loss: 0.3078944683074951, requires_grad = True
# Epoch 62/100, Loss: 0.3078944683074951
# Epoch 63 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 63 - Loss: 0.3075987696647644, requires_grad = True
# Epoch 63/100, Loss: 0.3075987696647644
# Epoch 64 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 64 - Loss: 0.30732977390289307, requires_grad = True
# Epoch 64/100, Loss: 0.30732977390289307
# Epoch 65 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 65 - Loss: 0.30706143379211426, requires_grad = True
# Epoch 65/100, Loss: 0.30706143379211426
# Epoch 66 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 66 - Loss: 0.30676671862602234, requires_grad = True
# Epoch 66/100, Loss: 0.30676671862602234
# Epoch 67 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 67 - Loss: 0.30652132630348206, requires_grad = True
# Epoch 67/100, Loss: 0.30652132630348206
# Epoch 68 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 68 - Loss: 0.3062658905982971, requires_grad = True
# Epoch 68/100, Loss: 0.3062658905982971
# Epoch 69 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 69 - Loss: 0.3060164451599121, requires_grad = True
# Epoch 69/100, Loss: 0.3060164451599121
# Epoch 70 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 70 - Loss: 0.3057864308357239, requires_grad = True
# Epoch 70/100, Loss: 0.3057864308357239
# Epoch 71 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 71 - Loss: 0.30553802847862244, requires_grad = True
# Epoch 71/100, Loss: 0.30553802847862244
# Epoch 72 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 72 - Loss: 0.30531999468803406, requires_grad = True
# Epoch 72/100, Loss: 0.30531999468803406
# Epoch 73 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 73 - Loss: 0.3050976097583771, requires_grad = True
# Epoch 73/100, Loss: 0.3050976097583771
# Epoch 74 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 74 - Loss: 0.3048763871192932, requires_grad = True
# Epoch 74/100, Loss: 0.3048763871192932
# Epoch 75 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 75 - Loss: 0.3046607971191406, requires_grad = True
# Epoch 75/100, Loss: 0.3046607971191406
# Epoch 76 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 76 - Loss: 0.3044295310974121, requires_grad = True
# Epoch 76/100, Loss: 0.3044295310974121
# Epoch 77 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 77 - Loss: 0.3042159676551819, requires_grad = True
# Epoch 77/100, Loss: 0.3042159676551819
# Epoch 78 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 78 - Loss: 0.30399465560913086, requires_grad = True
# Epoch 78/100, Loss: 0.30399465560913086
# Epoch 79 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 79 - Loss: 0.3037806749343872, requires_grad = True
# Epoch 79/100, Loss: 0.3037806749343872
# Epoch 80 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 80 - Loss: 0.30356624722480774, requires_grad = True
# Epoch 80/100, Loss: 0.30356624722480774
# Epoch 81 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 81 - Loss: 0.30335259437561035, requires_grad = True
# Epoch 81/100, Loss: 0.30335259437561035
# Epoch 82 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 82 - Loss: 0.3031507432460785, requires_grad = True
# Epoch 82/100, Loss: 0.3031507432460785
# Epoch 83 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 83 - Loss: 0.30294349789619446, requires_grad = True
# Epoch 83/100, Loss: 0.30294349789619446
# Epoch 84 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 84 - Loss: 0.3027438521385193, requires_grad = True
# Epoch 84/100, Loss: 0.3027438521385193
# Epoch 85 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 85 - Loss: 0.30253833532333374, requires_grad = True
# Epoch 85/100, Loss: 0.30253833532333374
# Epoch 86 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 86 - Loss: 0.3023410141468048, requires_grad = True
# Epoch 86/100, Loss: 0.3023410141468048
# Epoch 87 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 87 - Loss: 0.3021414279937744, requires_grad = True
# Epoch 87/100, Loss: 0.3021414279937744
# Epoch 88 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 88 - Loss: 0.3019448220729828, requires_grad = True
# Epoch 88/100, Loss: 0.3019448220729828
# Epoch 89 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 89 - Loss: 0.30174675583839417, requires_grad = True
# Epoch 89/100, Loss: 0.30174675583839417
# Epoch 90 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 90 - Loss: 0.30155277252197266, requires_grad = True
# Epoch 90/100, Loss: 0.30155277252197266
# Epoch 91 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 91 - Loss: 0.30136147141456604, requires_grad = True
# Epoch 91/100, Loss: 0.30136147141456604
# Epoch 92 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 92 - Loss: 0.30116966366767883, requires_grad = True
# Epoch 92/100, Loss: 0.30116966366767883
# Epoch 93 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 93 - Loss: 0.3009778559207916, requires_grad = True
# Epoch 93/100, Loss: 0.3009778559207916
# Epoch 94 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 94 - Loss: 0.30078446865081787, requires_grad = True
# Epoch 94/100, Loss: 0.30078446865081787
# Epoch 95 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 95 - Loss: 0.3005951941013336, requires_grad = True
# Epoch 95/100, Loss: 0.3005951941013336
# Epoch 96 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 96 - Loss: 0.30040496587753296, requires_grad = True
# Epoch 96/100, Loss: 0.30040496587753296
# Epoch 97 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 97 - Loss: 0.3002166450023651, requires_grad = True
# Epoch 97/100, Loss: 0.3002166450023651
# Epoch 98 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 98 - Loss: 0.3000268340110779, requires_grad = True
# Epoch 98/100, Loss: 0.3000268340110779
# Epoch 99 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 99 - Loss: 0.29984062910079956, requires_grad = True
# Epoch 99/100, Loss: 0.29984062910079956
# Epoch 100 - Model Output: Shape = torch.Size([26048]), requires_grad = True
# Epoch 100 - Loss: 0.29965588450431824, requires_grad = True
# Epoch 100/100, Loss: 0.29965588450431824

# %%
from sklearn.metrics import confusion_matrix

# 평가
model.eval()
with torch.no_grad():
    predictions = model(X_categ_test_tensor, X_cont_test_tensor, x_categ_test_enc, x_cont_test_enc).squeeze()
    predictions = torch.sigmoid(predictions).cpu().numpy()
    pred_labels = (predictions > 0.5).astype(int)

    # 성능 지표 계산
    accuracy = accuracy_score(y_test, pred_labels)
    auroc = roc_auc_score(y_test, predictions)
    precision = precision_score(y_test, pred_labels)
    recall = recall_score(y_test, pred_labels)
    f1 = f1_score(y_test, pred_labels)

    # 공정성 지표 계산
    sensitive_attr = X_categ_test_tensor[:, categorical_columns.index('sex')].cpu().numpy()  # gender 컬럼
    group_0 = sensitive_attr == 0  # 예: 남성
    group_1 = sensitive_attr == 1  # 예: 여성

    # Demographic Parity
    dp = abs(pred_labels[group_0].mean() - pred_labels[group_1].mean())

    # Equal Opportunity
    eo = abs(pred_labels[group_0 & (y_test == 1)].mean() - pred_labels[group_1 & (y_test == 1)].mean())

    # Equality of Odds
    group_0_tpr = pred_labels[group_0 & (y_test == 1)].mean()
    group_1_tpr = pred_labels[group_1 & (y_test == 1)].mean()
    group_0_fpr = pred_labels[group_0 & (y_test == 0)].mean()
    group_1_fpr = pred_labels[group_1 & (y_test == 0)].mean()
    eop = abs(group_0_tpr - group_1_tpr) + abs(group_0_fpr - group_1_fpr)

# 평가 결과 출력
print("\n모델 평가 결과:")
print(f"정확도 (Accuracy): {accuracy:.4f}")
print(f"AUROC: {auroc:.4f}")
print(f"정밀도 (Precision): {precision:.4f}")
print(f"재현율 (Recall): {recall:.4f}")
print(f"F1 점수 (F1-Score): {f1:.4f}")

# 공정성 지표 출력
print("\n공정성 지표:")
print(f"Demographic Parity (DP): {dp:.4f}")
print(f"Equal Opportunity (EO): {eo:.4f}")
print(f"Equality of Odds (EOP): {eop:.4f}")
# Out:
# 모델 평가 결과:
# 정확도 (Accuracy): 0.8615
# AUROC: 0.9183
# 정밀도 (Precision): 0.7416
# 재현율 (Recall): 0.6507
# F1 점수 (F1-Score): 0.6932
#
# 공정성 지표:
# Demographic Parity (DP): 0.1975
# Equal Opportunity (EO): 0.1010
# Equality of Odds (EOP): 0.1869
